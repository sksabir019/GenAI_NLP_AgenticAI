# %%
l = [4,5,56,6,67]

# %%
l.append(345)

# %%
l
# Out:
# [4, 5, 56, 6, 67, 'sudh', 345]

# %%
l.extend(3534)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 l.extend(3534)
#
# TypeError: 'int' object is not iterable

# %%
l.extend("sudh")

# %%
l
# Out:
# [4, 5, 56, 6, 67, 'sudh', 345, 's', 'u', 'd', 'h']

# %%
l.extend([345,56,56,566,776,78])

# %%
l
# Out:
# [4, 5, 56, 6, 67, 'sudh', 345, 's', 'u', 'd', 'h', 345, 56, 56, 566, 776, 78]

# %%
pip install pinecone
# Out:
# Collecting pinecone
#   Using cached pinecone-6.0.2-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: certifi>=2019.11.17 in c:\users\scl\anaconda3\envs\fastmcp_demo\lib\site-packages (from pinecone) (2025.1.31)
# Collecting pinecone-plugin-interface<0.0.8,>=0.0.7 (from pinecone)
#   Using cached pinecone_plugin_interface-0.0.7-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\scl\anaconda3\envs\fastmcp_demo\lib\site-packages (from pinecone) (2.9.0.post0)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\scl\anaconda3\envs\fastmcp_demo\lib\site-packages (from pinecone) (4.13.2)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\scl\anaconda3\envs\fastmcp_demo\lib\site-packages (from pinecone) (2.4.0)
# Requirement already satisfied: six>=1.5 in c:\users\scl\anaconda3\envs\fastmcp_demo\lib\site-packages (from python-dateutil>=2.5.3->pinecone) (1.17.0)
# Using cached pinecone-6.0.2-py3-none-any.whl (421 kB)
# Using cached pinecone_plugin_interface-0.0.7-py3-none-any.whl (6.2 kB)
# Installing collected packages: pinecone-plugin-interface, pinecone
# Successfully installed pinecone-6.0.2 pinecone-plugin-interface-0.0.7
# Note: you may need to restart the kernel to use updated packages.

# %%
from pinecone import Pinecone, ServerlessSpec

pc = Pinecone(key="your-api-key", environment="your-environment")
print(pc)
# Out:
# <pinecone.control.pinecone.Pinecone object at 0x000001D95925BFA0>

# %%
index_name = "sudhanshu"

pc.create_index(
    name=index_name,
    dimension=1536, # Replace with your model dimensions
    metric="cosine", # Replace with your model metric
    spec=ServerlessSpec(
        cloud="aws",
        region="us-east-1"
    ) 
)
# Out:
# {
#     "name": "sudhanshu",
#     "metric": "cosine",
#     "host": "sudhanshu-gcjuw7y.svc.aped-4627-b74a.pinecone.io",
#     "spec": {
#         "serverless": {
#             "cloud": "aws",
#             "region": "us-east-1"
#         }
#     },
#     "status": {
#         "ready": true,
#         "state": "Ready"
#     },
#     "vector_type": "dense",
#     "dimension": 1536,
#     "deletion_protection": "disabled",
#     "tags": null
# }

# %%
pc.list_indexes()
# Out:
# [
#     {
#         "name": "sudhanshu",
#         "metric": "cosine",
#         "host": "sudhanshu-gcjuw7y.svc.aped-4627-b74a.pinecone.io",
#         "spec": {
#             "serverless": {
#                 "cloud": "aws",
#                 "region": "us-east-1"
#             }
#         },
#         "status": {
#             "ready": true,
#             "state": "Ready"
#         },
#         "vector_type": "dense",
#         "dimension": 1536,
#         "deletion_protection": "disabled",
#         "tags": null
#     }
# ]

# %%
pc.delete_index("sudhanshu")

# %%
index_name = "sudhanshu"

pc.create_index(
    name=index_name,
    dimension=1536, # Replace with your model dimensions
    metric="cosine", # Replace with your model metric
    spec=ServerlessSpec(
        cloud="aws",
        region="us-east-1"
    ) 
)
# Out:
# {
#     "name": "sudhanshu",
#     "metric": "cosine",
#     "host": "sudhanshu-gcjuw7y.svc.aped-4627-b74a.pinecone.io",
#     "spec": {
#         "serverless": {
#             "cloud": "aws",
#             "region": "us-east-1"
#         }
#     },
#     "status": {
#         "ready": true,
#         "state": "Ready"
#     },
#     "vector_type": "dense",
#     "dimension": 1536,
#     "deletion_protection": "disabled",
#     "tags": null
# }

# %%
import requests
import numpy as np

def generate_embeddings(data):
    url = "https://api.euron.one/api/v1/euri/alpha/embeddings"
    headers = {
        "Content-Type": "application/json",
        "Authorization": "Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJhNTM3YzM3Zi0xNmFkLTRjZTUtYjRhMC0wNTNjYTIyNzE1YTgiLCJlbWFpbCI6InN1ZGhhbnNodUBldXJvbi5vbmUiLCJpYXQiOjE3NDMyMzkyNTYsImV4cCI6MTc3NDc3NTI1Nn0.HRHeCucOK0hPVZQwyvNoD0GaHarvHNivjJ2l6-xU1HA"
    }
    payload = {
        "input":data,
        "model": "text-embedding-3-small"
    }

    response = requests.post(url, headers=headers, json=payload)
    data = response.json()
    
    # Convert to numpy array for vector operations
    embedding = np.array(data['data'][0]['embedding'])
    
    print(f"Generated embedding with shape: {embedding.shape}")
    print(f"First 5 values: {embedding[:5]}")
    
    # Example: Calculate vector norm
    norm = np.linalg.norm(embedding)
    print(f"Vector norm: {norm}")
    
    return embedding

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\scl\anaconda3\envs\fastmcp_demo\lib\site-packages (2.2.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
embeddings_data = generate_embeddings("this is my own data for sudhanshu kuamr")
# Out:
# Generated embedding with shape: (1536,)
# First 5 values: [-0.01410448 -0.00497662  0.0744995  -0.01529552 -0.00535274]
# Vector norm: 0.9999999358979663

# %%
embeddings_data
# Out:
# array([-0.01410448, -0.00497662,  0.0744995 , ..., -0.00457264,
#         0.00186667, -0.02174527], shape=(1536,))

# %%
index = pc.Index('sudhanshu')
index.upsert([("item-id-001",embeddings_data.tolist(),{"name":"sudhanshu"})])
# Out:
# {'upserted_count': 1}

# %%
index.upsert( vectors=[ { "id": "item-id-oo1", "values": embeddings_data.tolist(), "metadata": { "text": "Lorem Ipsum is simply dummy text of the printing and typesetting industry." } } ], batch_size=1 )
# Out:
# {'upserted_count': 1}

# %%
index.upsert( vectors =[ ("item-id-002", embeddings_data.tolist(),{"name":"ankit warathe", "info":"personal info"}) ] )
# Out:
# {'upserted_count': 1}

# %%
index.fetch(ids=["item-id-002"])
# Out:
# FetchResponse(namespace='', vectors={'item-id-002': Vector(id='item-id-002', values=[-0.0141044781, -0.00497661717, 0.0744995, -0.0152955232, -0.00535273645, -0.00393532356, -0.00576716429, 0.0634666681, -0.00308383093, -0.0183741301, 0.0304517429, -0.0466666706, -0.0329592042, -0.0271641798, 0.0639681593, 0.0316497535, -0.0240437817, -0.00739005, 0.00278781098, 0.0505114459, 0.0207980108, 0.00286965189, 0.034463685, -0.0281671658, 0.00882487558, -0.0257154237, -0.0207562204, -0.0170368161, 0.0153930355, -0.0487005, -0.0195582099, -0.0385870673, -0.00347736338, 0.00115621893, -0.00300721405, 0.0213830862, -0.0375005, 0.005502488, -0.0376398042, -0.0100995032, 0.00903383084, -0.061404977, 0.00936119445, 0.0265930369, -0.0122935325, -0.0197253749, -0.0471403, -0.0242666677, -0.0349930376, -0.0248238817, -0.0322348289, 0.016646767, 0.0313711464, 0.0552199036, 0.0369711444, 0.00182661705, 0.0183602, 0.0723263696, -0.0233054738, -0.0533253774, 0.0034895523, -0.00529353274, -0.000330845796, 0.0290308464, -0.00805870723, -0.030507464, 0.00300199026, 0.00587860728, -0.014863682, -0.00851144362, 0.0408159234, 0.0278049763, 0.00549552264, -0.00118756224, -0.00804477651, -0.020951245, -0.00140957721, -0.0155184083, 0.0158248767, 0.0039527365, -0.0239044782, 0.00610497547, 0.0301731359, -0.0169532355, -0.0582288578, -0.00592736341, -0.102861695, 0.0270666685, -0.0751124397, -0.0150029855, -0.0426825881, 0.00699651754, -0.0195582099, 0.0183741301, 0.034185078, -0.0106218914, 0.0407880619, -0.0123422891, 0.0119313439, 0.0171761196, -0.00229850761, 0.0249771159, 0.0742766187, 0.00481990073, 0.0459144302, 0.0210766178, 0.053576123, -0.0463880636, -0.0119522391, 0.0154348267, -0.0200039819, -0.0139024882, -0.0102109462, 0.0127810948, -0.0298666675, 0.0145154232, 0.0199900512, -0.00999502558, -0.0203522407, -0.0175940301, -0.0157830846, -0.00367761217, 0.0402029864, -0.0208119415, 0.0152258715, -0.00778009975, 0.0461930372, -0.0527960211, -0.0189174134, -0.0318169184, 0.00344079616, -0.0782328397, 0.00317960209, -0.0520716459, -0.00377164199, -0.0041547264, -0.0161731355, 0.0303681605, -0.0481432863, -0.0234865677, 0.0109771146, 0.040175125, 0.0257990062, 0.00611194037, -0.00805870723, -0.0262308475, -0.0210766178, 0.0377512462, -0.0065507465, 0.0154348267, -0.0278189071, 0.0379184112, 0.016089553, 0.0102457721, -0.00876218919, 0.00364626874, 0.0289194044, -0.0244059712, -0.00306815933, 0.00490348274, 0.0270109456, -0.039339304, -0.051012937, -0.0286965184, -0.0007587687, 0.0124398014, -0.0476417951, -0.0333771147, -0.053966172, -0.0596218929, 0.00990447775, -0.00786368176, 0.020394031, -0.063243784, -0.024809951, 0.0378069654, -0.0231801011, -0.0139930351, -0.0317054726, -0.00631044805, 0.00783582125, 0.0159502495, 0.013268657, 0.0464995056, -0.0121681597, 0.0154626872, 0.068648763, 0.0352995023, 0.0203661695, -0.0090407962, 0.031621892, 0.0386149287, 0.0259940308, 0.0183602, -0.0186666679, 0.0122029856, 0.0426268689, 0.0444935337, -0.0158945285, -0.0012911692, 0.0140835829, -0.0371104479, -0.0176079609, 0.00156629365, -0.00138694036, -0.0312318429, -0.0138398018, -0.00858109538, -0.000895024918, 0.0213552248, 0.043295525, 0.0368597023, 0.00271293544, 0.0266348273, -0.0243781097, -0.0152815925, -0.0507621914, -0.0320398025, 0.0189034827, 0.00872039888, 0.0143900504, 0.0236815941, 0.0918288603, 0.0249771159, -0.0340457745, 0.0295323394, 0.0270945281, -0.0014121891, -0.0358009972, -0.0411223918, -0.0160756223, 0.0140696522, -0.00278084585, 0.0148915434, 0.0112905474, -0.0178865679, 0.0184019916, 0.0136099504, -0.0146547267, 0.00351044792, -0.0577830859, 0.00816318486, -0.000688246277, 0.0422646776, -0.00831641816, 0.0124606974, -0.000794900523, -0.00163942797, -0.0375283584, 0.0520995036, -0.0107890554, 0.0187781099, -0.00880398, -0.0122169163, -0.0610706508, -0.0475860722, -0.0464159213, 0.0332935341, 0.0353552252, 0.0293651763, -0.00628955243, -0.00125808467, -0.0502049774, 0.0285850763, -0.0342686586, 0.0376398042, -0.00623034872, 0.043044779 ...

# %%
text = "my name is sudhanshu"
embedings_to_search = generate_embeddings(text)
result = index.query(vector=embedings_to_search.tolist(),
            top_k = 2,
            include_metadata = True)
print(result)
# Out:
# Generated embedding with shape: (1536,)
# First 5 values: [-0.00645238 -0.02682346 -0.02852873 -0.00903333 -0.06539947]
# Vector norm: 1.0000000004372394
# {'matches': [{'id': 'item-id-002',
#               'metadata': {'info': 'personal info', 'name': 'ankit warathe'},
#               'score': 0.625566661,
#               'values': []},
#              {'id': 'item-id-001',
#               'metadata': {'name': 'sudhanshu'},
#               'score': 0.625566661,
#               'values': []}],
#  'namespace': '',
#  'usage': {'read_units': 6}}

# %%
index.upsert([("item-id-001",embeddings_data.tolist(),{"name":"sudhanshu"}),
              ("item-id-002",embeddings_data.tolist(),{"name":"sudhanshu"}),
              ("item-id-003",embeddings_data.tolist(),{"name":"sudhanshu"}),
              ("item-id-004",embeddings_data.tolist(),{"name":"sudhanshu"}),
              ("item-id-005",embeddings_data.tolist(),{"name":"sudhanshu"}),
              ("item-id-006",embeddings_data.tolist(),{"name":"sudhanshu"}),
              ("item-id-007",embeddings_data.tolist(),{"name":"sudhanshu"}),
              ("item-id-008",embeddings_data.tolist(),{"name":"sudhanshu"}),
              ("item-id-009",embeddings_data.tolist(),{"name":"sudhanshu"})],
             
             namespace = 'sudh1')
# Out:
# {'upserted_count': 9}

# %%
index.upsert([("item-id-001",embeddings_data.tolist(),{"name":"sudhanshu"}),
              ("item-id-002",embeddings_data.tolist(),{"name":"sudhanshu"}),
              ("item-id-003",embeddings_data.tolist(),{"name":"sudhanshu"}),
              ("item-id-004",embeddings_data.tolist(),{"name":"sudhanshu"}),
              ("item-id-005",embeddings_data.tolist(),{"name":"sudhanshu"}),
              ("item-id-006",embeddings_data.tolist(),{"name":"sudhanshu"}),
              ("item-id-007",embeddings_data.tolist(),{"name":"sudhanshu"}),
              ("item-id-008",embeddings_data.tolist(),{"name":"sudhanshu"}),
              ("item-id-009",embeddings_data.tolist(),{"name":"sudhanshu"})],
             
             namespace = 'sudh2')
# Out:
# {'upserted_count': 9}

# %%
pip install weaviate-client
# Out:
# Collecting weaviate-client
#   Downloading weaviate_client-4.14.1-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: httpx<0.29.0,>=0.26.0 in c:\users\scl\anaconda3\envs\fastmcp_demo\lib\site-packages (from weaviate-client) (0.28.1)
# Collecting validators==0.34.0 (from weaviate-client)
#   Using cached validators-0.34.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting authlib<1.3.2,>=1.2.1 (from weaviate-client)
#   Downloading Authlib-1.3.1-py2.py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.8.0 in c:\users\scl\anaconda3\envs\fastmcp_demo\lib\site-packages (from weaviate-client) (2.11.3)
# Collecting grpcio<2.0.0,>=1.66.2 (from weaviate-client)
#   Using cached grpcio-1.71.0-cp310-cp310-win_amd64.whl.metadata (4.0 kB)
# Collecting grpcio-tools<2.0.0,>=1.66.2 (from weaviate-client)
#   Downloading grpcio_tools-1.71.0-cp310-cp310-win_amd64.whl.metadata (5.5 kB)
# Collecting grpcio-health-checking<2.0.0,>=1.66.2 (from weaviate-client)
#   Downloading grpcio_health_checking-1.71.0-py3-none-any.whl.metadata (1.0 kB)
# Collecting deprecation<3.0.0,>=2.1.0 (from weaviate-client)
#   Using cached deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Collecting cryptography (from authlib<1.3.2,>=1.2.1->weaviate-client)
#   Downloading cryptography-44.0.3-cp39-abi3-win_amd64.whl.metadata (5.7 kB)
# Requirement already satisfied: packaging in c:\users\scl\anaconda3\envs\fastmcp_demo\lib\site-packages (from deprecation<3.0.0,>=2.1.0->weaviate-client) (25.0)
# Collecting protobuf<6.0dev,>=5.26.1 (from grpcio-health-checking<2.0.0,>=1.66.2->weaviate-client)
#   Using cached protobuf-5.29.4-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Requirement already satisfied: setuptools in c:\users\scl\anaconda3\envs\fastmcp_demo\lib\site-packages (from grpcio-tools<2.0.0,>=1.66.2->weaviate-client) (75.8.0)
# Requirement already satisfied: anyio in c:\users\scl\anaconda3\envs\fastmcp_demo\lib\site-packages (from httpx<0.29.0,>=0.26.0->weaviate-client) (4.9.0)
# Requirement already satisfied: certifi in c:\users\scl\anaconda3\envs\fastmcp_demo\lib\site-packages (from httpx<0.29.0,>=0.26.0->weaviate-client) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\scl\anaconda3\envs\fastmcp_demo\lib\site-packages (from httpx<0.29.0,>=0.26.0->weaviate-client) (1.0.8)
# Requirement already satisfied: idna in c:\users\scl\anaconda3\envs\fastmcp_demo\lib\site-packages (from httpx<0.29.0,>=0.26.0->weaviate-client) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\scl\anaconda3\envs\fastmcp_demo\lib\site-packages (from httpcore==1.*->httpx<0.29.0,>=0.26.0->weaviate-client) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\scl\anaconda3\envs\fastmcp_demo\lib\site-packages (from pydantic<3.0.0,>=2.8.0->weaviate-client) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in c:\users\scl\anaconda3\envs\fastmcp_demo\lib\site-packages (from pydantic<3.0.0,>=2.8.0->weaviate-client) (2.33.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\scl\anaconda3\envs\fastmcp_demo\lib\site-packages (from pydantic<3.0.0,>=2.8.0->weaviate-client) (4.13.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\scl\anaconda3\envs\fastmcp_demo\lib\site-packages (from pydantic<3.0.0,>=2.8.0->weaviate-client) (0.4.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\scl\anaconda3\envs\fastmcp_demo\lib\site-packages (from anyio->httpx<0.29.0,>=0.26.0->weaviate-client) (1.2.2)
# Requirement already satisfied: sniffio>=1.1 in c:\users\scl\anaconda3\envs\fastmcp_demo\lib\site-packages (from anyio->httpx<0.29.0,>=0.26.0->weaviate-client) (1.3.1)
# Collecting cffi>=1.12 (from cryptography->authlib<1.3.2,>=1.2.1->weaviate-client)
#   Using cached cffi-1.17.1-cp310-cp310-win_amd64.whl.metadata (1.6 kB)
# Collecting pycparser (from cffi>=1.12->cryptography->authlib<1.3.2,>=1.2.1->weaviate-client)
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Downloading weaviate_client-4.14.1-py3-none-any.whl (442 kB)
# Using cached validators-0.34.0-py3-none-any.whl (43 kB)
# Downloading Authlib-1.3.1-py2.py3-none-any.whl (223 kB)
# Using cached deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Using cached grpcio-1.71.0-cp310-cp310-win_amd64.whl (4.3 MB)
# Downloading grpcio_health_checking-1.71.0-py3-none-any.whl (18 kB)
# Downloading grpcio_tools-1.71.0-cp310-cp310-win_amd64.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 1.1/1.1 MB 53.7 MB/s eta 0:00:00
# Using cached protobuf-5.29.4-cp310-abi3-win_amd64.whl (434 kB)
# Downloading cryptography-44.0.3-cp39-abi3-win_amd64.whl (3.2 MB)
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    ---------------------------------------- 3.2/3.2 MB 47.6 MB/s eta 0:00:00
# Using cached cffi-1.17.1-cp310-cp310-win_amd64.whl (181 kB)
# Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Installing collected packages: validators, pycparser, protobuf, grpcio, deprecation, grpcio-tools, grpcio-health-checking, cffi, cryptography, authlib, weaviate-client
# Successfully installed authlib-1.3.1 cffi-1.17.1 cryptography-44.0.3 deprecation-2.1.0 grpcio-1.71.0 grpcio-health-checking-1.71.0 grpcio-tools-1.71.0 protobuf-5.29.4 pycparser-2.22 validators-0.34.0 weaviate-client-4.14.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import weaviate
from weaviate.classes.init import Auth


# Connect to Weaviate Cloud
client = weaviate.connect_to_weaviate_cloud(
    cluster_url="llxuui3vtd6lfbsqw1emxg.c0.asia-southeast1.gcp.weaviate.cloud",
    auth_credentials=Auth.api_key("0ospeZdyjzFs6fNP2AwlzEjsXcCTeXGPSfJk"),
)

print(client.is_ready())
# Out:
# True

# %%
text_data = "this is to test my weaviate databsed by sudhanshu"
embedings   = generate_embeddings(text_data)
# Out:
# Generated embedding with shape: (1536,)
# First 5 values: [-0.01164255 -0.01081737  0.08393172 -0.01693335 -0.02432522]
# Vector norm: 1.0000000177512753

# %%
collection = client.collections.get("Document")
collection.data.insert(
    properties = {
        "text" :text_data,
        "author":"sudhanshu"
    },
    vector =embedings.tolist()
    
)
# Out:
# UUID('346f6f4d-c4b6-4ec0-a983-16b0498a3f3e')

# %%
test_search = "sudhanshu is mentor"
embedings_search_data = generate_embeddings(test_search)

result = collection.query.near_vector(
    near_vector = embedings_search_data.tolist(),
    limit = 1 
)
# Out:
# Generated embedding with shape: (1536,)
# First 5 values: [-0.03895542 -0.00112551  0.03618279 -0.01580398 -0.02324848]
# Vector norm: 0.9999999445699245

# %%
for i in result.objects:
    print(i.properties['text'])
# Out:
# this is to test my weaviate databsed by sudhanshu

# %%
result.objects
# Out:
# [GenerativeObject(uuid=_WeaviateUUIDInt('ad6d31f9-9262-4f56-bfee-f3da697715a6'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=None, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'text': 'this is to test my weaviate databsed by sudhanshu', 'author': 'sudhanshu'}, references=None, vector={}, collection='Document')]
